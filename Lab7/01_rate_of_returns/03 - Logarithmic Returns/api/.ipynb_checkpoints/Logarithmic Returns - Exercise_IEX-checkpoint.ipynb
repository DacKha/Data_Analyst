# %% [markdown]
# ## Logarithmic Returns

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

MSFT = yf.download('MSFT', start='2015-01-01')
print(MSFT.head())
# Out:
# C:\Users\KHA\AppData\Local\Temp\ipykernel_9520\2256767355.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   MSFT = yf.download('MSFT', start='2015-01-01')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2015-01-02  39.933041  40.496681  39.745163  39.847642  27913900
# 2015-01-05  39.565838  39.907436  39.497516  39.599995  39673900
# 2015-01-06  38.985126  39.924526  38.891186  39.608547  36447900
# 2015-01-07  39.480438  39.676858  38.848480  39.266938  29114100
# 2015-01-08  40.641876  40.778516  39.898897  39.924516  29645200

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT['log_return'] = np.log(MSFT['Close'] / MSFT['Close'].shift(1))
print (MSFT['log_return'])
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.009238
# 2015-01-06   -0.014786
# 2015-01-07    0.012625
# 2015-01-08    0.028994
#                 ...
# 2025-10-27    0.014994
# 2025-10-28    0.019654
# 2025-10-29   -0.000960
# 2025-10-30   -0.029591
# 2025-10-31   -0.015236
# Name: log_return, Length: 2725, dtype: float64

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
log_return_d = MSFT['log_return'].mean()
log_return_d
# Out:
# 0.0009406770587310148

# %%
log_return_a = MSFT['log_return'].mean() * 250
log_return_a
# Out:
# 0.2351692646827537

# %% [markdown]
# Print the result in a presentable form.

# %%
print (str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 23.517 %
