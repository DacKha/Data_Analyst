# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# a. Create a series object of 10 randomly generated integer values.

# %%
import pandas as pd 
import numpy as np

# %%
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.496513
# 1    0.763253
# 2    0.248785
# 3    0.936832
# 4    0.686110
# Name: Column 01, dtype: float64

# %% [markdown]
# b. Extract data from IEX for Ford from the 1st of January 2015. The ticker you need is ‘F’.

# %%
import yfinance as yf

# %%
F = yf.download('F', start='2015-01-01')
# Out:
# C:\Users\KHA\AppData\Local\Temp\ipykernel_25640\1425971115.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   F = yf.download('F', start='2015-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
print(F.head())
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker             F         F         F         F         F
# Date
# 2015-01-02  8.528311  8.689327  8.428370  8.656014  24777900
# 2015-01-05  8.195174  8.400609  8.156308  8.395056  44079700
# 2015-01-06  8.117444  8.272908  7.984189  8.261804  32981600
# 2015-01-07  8.350637  8.378399  8.200726  8.206278  26065300
# 2015-01-08  8.561626  8.594940  8.456133  8.550522  33943400
